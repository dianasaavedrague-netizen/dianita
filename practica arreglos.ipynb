# %%
#promedio
#saavedra diana

nota1 = 10
nota2 = 9
nota3 = 8
nota4 = 7
nota5 = 6
promedio = (nota1 + nota2 + nota3 + nota4 + nota5) / 5

print("nota1:", nota1)
print("nota2:", nota2)
print("nota3:", nota3)
print("nota4:", nota4)
print("nota5:", nota5)

print(f"Elpromedio es promedio:", promedio)
# Out:
# nota1: 10
# nota2: 9
# nota3: 8
# nota4: 7
# nota5: 6
# Elpromedio es promedio: 8.0
