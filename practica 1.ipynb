# %%
print("operadores matematicos")
print("realiza la suma de 4 + 4 =" , 4+4 )
print("realiza la resta 8 - 6 =" , 8-6)
# Out:
# operadores matematicos
# realiza la suma de 4 + 4 = 8
# realiza la resta 8 - 6 = 2

# %%
print("realiza la multipicacion 4 * 4 =" , 4*4)
print("realiza la multiplicacion 5 * 7 =" , 5*7)
print("realiza la multipicacion 8 * 9 =" ,8*9 )
print("realiza la multiplicacion 7 * 5 =" , 7*5)
print("realiza la multiplicacion 4 * 2 =" , 4*2)
print("realiza la multiplicacion 9 * 6 =" , 9*6)
print("reliza la multiplicacion 3 * 4 =" , 3*4)
print("realiza la multiplicacion 5 * 6 =" , 5*6)
print("reliza la multiplicacion 7 * 8 =" , 7*8)
print("realiza la multiplicacion 9 * 2 =" , 9*2)
# Out:
# realiza la multipicacion 4 * 4 = 16
# realiza la multiplicacion 5 * 7 = 35
# realiza la multipicacion 8 * 9 = 72
# realiza la multiplicacion 7 * 5 = 35
# realiza la multiplicacion 4 * 2 = 8
# realiza la multiplicacion 9 * 6 = 54
# reliza la multiplicacion 3 * 4 = 12
# realiza la multiplicacion 5 * 6 = 30
# reliza la multiplicacion 7 * 8 = 56
# realiza la multiplicacion 9 * 2 = 18

# %%
print("realiza la suma 2 + 3 =" , 2+3)
print("realiza la suma 4 + 5 =" , 4+5)
print("realiza la suma  6 + 7 =" , 6+7)
print("reliza la suma 8 + 9 =" , 8+9)
print("realiza la suma 10 + 1 =" , 10+1)
print("reliza la suma 12 + 3 =" , 12+3)
print("realiza la suma 14 + 6 =" , 14+6)
print("realiza la suma 15 + 5 =" , 15+5)
print("realiza la suma 20 + 4 =" , 20+4)
print("reliza la suma 25 + 5 =" , 25+5)
# Out:
# realiza la suma 2 + 3 = 5
# realiza la suma 4 + 5 = 9
# realiza la suma  6 + 7 = 13
# reliza la suma 8 + 9 = 17
# realiza la suma 10 + 1 = 11
# reliza la suma 12 + 3 = 15
# realiza la suma 14 + 6 = 20
# realiza la suma 15 + 5 = 20
# realiza la suma 20 + 4 = 24
# reliza la suma 25 + 5 = 30

# %%
print("realiza la resta 10 - 3 =" , 10-3)
print("reliza la resta 15 - 5 =" , 15-5)
print("realiza la resta 20 - 8 =" , 20-8)
print("realiza la resta 30 - 10 " , 30-10)
print("realiza la resta 50 - 25 =" , 50-25)
print("realiza la resta 18 - 9 =" , 18-9)
print("realiza la resta 40 - 12 =" , 40-12)
print("realiza la resta 60 - 20 =" , 60-20)
print("realiza la resta 70 - 30 =" , 70-30)
print("realiza la resta 100 - 45 =" , 100-45)
# Out:
# realiza la resta 10 - 3 = 7
# reliza la resta 15 - 5 = 10
# realiza la resta 20 - 8 = 12
# realiza la resta 30 - 10  20
# realiza la resta 50 - 25 = 25
# realiza la resta 18 - 9 = 9
# realiza la resta 40 - 12 = 28
# realiza la resta 60 - 20 = 40
# realiza la resta 70 - 30 = 40
# realiza la resta 100 - 45 = 55

# %%
print("realiza la division 8 / 2 =" , 8/2)
print("realiza la division 9 / 3 =" , 9/3)
print("realiza la division 10 / 5 =" , 10/5)
print("realiza la division 12 / 4 =" , 12/4)
print("realiza la divison 15 / 3 =" , 15/3)
print("realiza la division 16 / 8 =" , 16/8)
print("realiza la division 18 / 6 =" , 18/6)
print("realiza la division 20 / 4 =" , 20/4)
print("realiza la division 25 / 5 =" , 25/5)
print("realiza la division 30 / 6 =" , 30/6)
# Out:
# realiza la division 8 / 2 = 4.0
# realiza la division 9 / 3 = 3.0
# realiza la division 10 / 5 = 2.0
# realiza la division 12 / 4 = 3.0
# realiza la divison 15 / 3 = 5.0
# realiza la division 16 / 8 = 2.0
# realiza la division 18 / 6 = 3.0
# realiza la division 20 / 4 = 5.0
# realiza la division 25 / 5 = 5.0
# realiza la division 30 / 6 = 5.0
